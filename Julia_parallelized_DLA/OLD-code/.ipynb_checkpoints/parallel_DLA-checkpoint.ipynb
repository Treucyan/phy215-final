# %%
using BenchmarkTools
using Plots

include("parallelized_DLA.jl")
# Out:
# WARNING: replacing module Utils.
# WARNING: replacing module DLA_parallel.
# Main.DLA_parallel

# %% [markdown]
# # Parallel DLA implementation

# %% [markdown]
# ## Initialize constants

# %%
birth_radius = 12  # larger starting radius minimizes halo effect
num_walkers = 80
num_steps = 1000
desired_cluster_size = 2000
;

# %%
@time cluster = DLA_parallel.parallelized_DLA(num_walkers, num_steps, desired_cluster_size, birth_radius)
# Out:
#  2013385.840852 seconds (4.28 G allocations: 318.564 GiB, 5.74% gc time, 0.22% compilation time)
# 2013-element Vector{Any}:
#  [0, 0]
#  [1, 0]
#  [1, 1]
#  [1, 2]
#  [2, 2]
#  [-1, 0]
#  [-2, 0]
#  [1, -1]
#  [2, 3]
#  [-3, 0]
#  [2, 4]
#  [-2, 1]
#  [-4, 0]
#  ⋮
#  [-44, -33]
#  [-54, 0]
#  [54, -7]
#  [53, -19]
#  [-54, 2]
#  [10, -45]
#  [-49, 26]
#  [-55, -8]
#  [35, -29]
#  [54, -6]
#  [-50, 18]
#  [-49, 27]

# %%
fig = scatter()
scatter!(fig, ([v[1] for v in cluster], [v[2] for v in cluster]), label="")

r = birth_radius
θ = range(-π, π, 1000)
plot!(fig, (r * cos.(θ), r * sin.(θ)), color="black", label="")

# %% [markdown]
# # Appendix A: Circle generation

# %% [markdown]
# ### Demonstration

# %%
r = 16

# Discrete circle
circle_points = Utils.get_circle_points(r)

# Continuous circle
θ = range(-π, π, 1000)
xpoints = r * cos.(θ)
ypoints = r * sin.(θ)
;

# %%
s = scatter()
for (px, py) in circle_points
    scatter!(s, (px, py), color="black", label="")
end
plot!(s, (xpoints, ypoints), color = "black", label="")

# %% [markdown]
# ### Benchmarking

# %%
r = 1_000_000
@btime Utils.get_circle_points($r)
;
# Out:
#   24.523 ns (1 allocation: 16 bytes)
